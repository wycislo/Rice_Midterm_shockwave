# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint


#url="https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02"
url="https://www.seismicportal.eu/mtws/api/search?starttime=1970-01-01T00%3A00%3A00Z&endtime=2021-08-26T00%3A00%3A00Z&minmag=2.5&format=json&downloadAsFile=false&orderby=time-desc&offset=0&limit=30000"
sample = requests.get(url)

sample_json = sample.json()

pprint(sample_json)
# Out:
# [{'deltatime': '@ 33 mins 39.8 secs',
#   'ev_depth': 12,
#   'ev_event_time': '2021-08-25 21:04:20.2 UTC',
#   'ev_id': 11535,
#   'ev_latitude': 15.47,
#   'ev_longitude': -88.34,
#   'ev_mag_type': 'mw',
#   'ev_mag_value': 5.2,
#   'ev_region': 'HONDURAS',
#   'ev_unid': '20210825_0000209',
#   'full_count': 23480,
#   'mt_axe_exp': 16,
#   'mt_centroid_time': '2021-08-25 21:04:20.7 UTC',
#   'mt_depth': 15,
#   'mt_dip_1': 45,
#   'mt_dip_2': 44,
#   'mt_id': 23533,
#   'mt_latitude': 15.52,
#   'mt_longitude': -88.21,
#   'mt_m0': 7.2,
#   'mt_m0_exp': 16,
#   'mt_mpp': 6.92,
#   'mt_mrp': -0.02,
#   'mt_mrr': -7.34,
#   'mt_mrt': 0.49,
#   'mt_mtp': 0.94,
#   'mt_mtt': 0.41,
#   'mt_mw': 5.2,
#   'mt_naz': 8,
#   'mt_nplung': 3,
#   'mt_nval': 0.308,
#   'mt_paz': 185,
#   'mt_per_clvd': 8.46,
#   'mt_per_dc': 91.5,
#   'mt_per_iso': 0.05,
#   'mt_pplung': 86,
#   'mt_preferred': True,
#   'mt_pval': -7.371,
#   'mt_rake_1': -84,
#   'mt_rake_2': -95,
# ...
